# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as ply

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('googleplaystore.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.sample(3)
# Out:
#                                                      App         Category  \
# 5190                         ParaTek Ai Speech generator            TOOLS
# 10338  Theme for Galaxy Note FE Launcher | Live Wallp...  PERSONALIZATION
# 8833                                          DS-11 form         BUSINESS
#
#        Rating Reviews  Size Installs  Type Price Content Rating  \
# 5190      3.6     448  4.3M  50,000+  Free     0       Everyone
# 10338     NaN       2   26M     100+  Free     0       Everyone
# 8833      NaN       3   28M     100+  Free     0       Everyone
#
#                 Genres       Last Updated Current Ver Android Ver
# 5190             Tools     March 23, 2017         1.9  1.6 and up
# 10338  Personalization  December 22, 2017         1.0  4.0 and up
# 8833          Business     April 27, 2018       1.7.7  4.1 and up

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(483)

# %%
df=df.drop_duplicates()

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df[df['Reviews'].str.isnumeric()==False]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df_copy=df.copy()

# %%
df_copy.reset_index(drop=True,inplace=True)

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_copy[df_copy['Reviews'].str.isnumeric()==False]
# Out:
#                                           App Category  Rating Reviews  \
# 9990  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9990  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9990       1.0.19  4.0 and up         NaN

# %%
df_copy=df_copy.drop(df_copy.index[9990])

# %%
df_copy['Reviews']=df_copy['Reviews'].astype(int)

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
def size_conv(item):
  if str(item)[-1]=='M':
    res=float(item.replace('M',''))*1024
    item=res
    return item
  elif str(item)[-1]=='k':
    res=float(item.replace('k',''))
    item=res
    return item
  elif str(item)=='Varies with device':
    item=1000
    return item

# %%
df_copy['Size']=df_copy['Size'].apply(size_conv)

# %%
df_copy['Size']=df_copy['Size'].astype(float)

# %%
df_copy['Installs']=df_copy['Installs'].str.replace('+','').str.replace(',','')

# %%
df_copy['Installs'] =df_copy['Installs'].astype(int)

# %%
char_to_remove=['$',',','+']
cols_to_remove=['Price']

for char in char_to_remove:
  for col in cols_to_remove:
    df_copy[col]=df_copy[col].str.replace(char,'')

# %%
df_copy['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
df_copy['Price']=df_copy['Price'].astype(float)

# %%
df_copy['Last Updated']
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10353       July 25, 2017
# 10354        July 6, 2018
# 10355    January 20, 2017
# 10356    January 19, 2015
# 10357       July 25, 2018
# Name: Last Updated, Length: 10357, dtype: object

# %%
df_copy['Last Updated']=pd.to_datetime(df_copy['Last Updated'])

# %%
df_copy['Day']=df_copy['Last Updated'].dt.day

# %%
df_copy['Month']=df_copy['Last Updated'].dt.month

# %%
df_copy['Year']=df_copy['Last Updated'].dt.year

# %%
df_copy.drop('Last Updated',axis=1)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy['Android Ver']=df_copy['Android Ver'].str.replace('and up','')

# %%
df_copy['Android Ver'].unique()
# Out:
# array(['4.0.3 ', '4.2 ', '4.4 ', '2.3 ', '3.0 ', '4.1 ', '4.0 ', '2.3.3 ',
#        'Varies with device', '2.2 ', '5.0 ', '6.0 ', '1.6 ', '1.5 ',
#        '2.1 ', '7.0 ', '5.1 ', '4.3 ', '4.0.3 - 7.1.1', '2.0 ', '3.2 ',
#        '4.4W ', '7.1 ', '7.0 - 7.1.1', '8.0 ', '5.0 - 8.0', '3.1 ',
#        '2.0.1 ', '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 ', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
df_copy['Android Ver']=df_copy['Android Ver'].str.replace('Varies with device','0.0').str.replace('W','')

# %%
df_copy['Android Ver'].unique()
# Out:
# array(['4.0.3 ', '4.2 ', '4.4 ', '2.3 ', '3.0 ', '4.1 ', '4.0 ', '2.3.3 ',
#        '0.0', '2.2 ', '5.0 ', '6.0 ', '1.6 ', '1.5 ', '2.1 ', '7.0 ',
#        '5.1 ', '4.3 ', '4.0.3 - 7.1.1', '2.0 ', '3.2 ', '7.1 ',
#        '7.0 - 7.1.1', '8.0 ', '5.0 - 8.0', '3.1 ', '2.0.1 ',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 ', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
sns.countplot(x=df_copy['Type'])
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
sns.countplot(x=df_copy['Content Rating'])
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
sns.distplot(df_copy['Price'],kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.kdeplot(x=df_copy['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.distplot(df_copy['Rating'],kde=True)
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
df_copy['Category'].value_counts().plot.pie(y=df_copy['Category'],autopct='%1.1f')
# Out:
# <Axes: ylabel='count'>

# %%
category=df_copy['Category'].value_counts()[0:10]
category=category.reset_index()

# %%
category
# Out:
#           Category  count
# 0           FAMILY   1943
# 1             GAME   1121
# 2            TOOLS    843
# 3         BUSINESS    427
# 4          MEDICAL    408
# 5     PRODUCTIVITY    407
# 6  PERSONALIZATION    388
# 7        LIFESTYLE    373
# 8    COMMUNICATION    366
# 9          FINANCE    360

# %%
sns.barplot(category,x=category['Category'],y=category['count'],palette='crest')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
df_copy.groupby('Category')['Installs'].sum().sort_values(ascending=False).reset_index()
# Out:
#                Category     Installs
# 0                  GAME  31544024415
# 1         COMMUNICATION  24152276251
# 2                SOCIAL  12513867902
# 3          PRODUCTIVITY  12463091369
# 4                 TOOLS  11452771915
# 5                FAMILY  10041692505
# 6           PHOTOGRAPHY   9721247655
# 7      TRAVEL_AND_LOCAL   6361887146
# 8         VIDEO_PLAYERS   6222002720
# 9    NEWS_AND_MAGAZINES   5393217760
# 10             SHOPPING   2573348785
# 11        ENTERTAINMENT   2455660000
# 12      PERSONALIZATION   2074494782
# 13  BOOKS_AND_REFERENCE   1916469576
# 14               SPORTS   1528574498
# 15   HEALTH_AND_FITNESS   1361022512
# 16             BUSINESS    863664865
# 17              FINANCE    770348734
# 18  MAPS_AND_NAVIGATION    724281890
# 19            LIFESTYLE    534823539
# 20            EDUCATION    533952000
# 21              WEATHER    426100520
# 22       FOOD_AND_DRINK    257898751
# 23               DATING    206536107
# ...

# %%
sns.boxplot(df_copy['Rating'])
# Out:
# <Axes: ylabel='Rating'>

# %%
sns.boxplot(df_copy,x='Installs',y='Rating',)
# Out:
# <Axes: xlabel='Installs', ylabel='Rating'>

# %%
df_copy.groupby(['Category','Type'])['Installs'].sum().sort_values(ascending=False)
# Out:
# Category            Type
# GAME                Free    31522924450
# COMMUNICATION       Free    24150916201
# SOCIAL              Free    12513861902
# PRODUCTIVITY        Free    12461679314
# TOOLS               Free    11451044474
#                                ...
# SHOPPING            Paid          10100
# SOCIAL              Paid           6000
# NEWS_AND_MAGAZINES  Paid           5500
# LIBRARIES_AND_DEMO  Paid            100
# EVENTS              Paid              1
# Name: Installs, Length: 63, dtype: int64

# %%
df_copy.groupby(['Category','App'])['Reviews'].sum().sort_values(ascending=False)
# Out:
# Category         App
# SOCIAL           Instagram                                   199664676
#                  Facebook                                    156286514
# GAME             Subway Surfers                              138606606
# COMMUNICATION    WhatsApp Messenger                          138228988
#                  Messenger – Text and Video Chat for Free    113289425
#                                                                ...
# FAMILY           EBook For SAP BW ON HANA Learning Free              0
#                  EB Demo for Android                                 0
# PERSONALIZATION  Wallpapers FN Herstal FNP 9                         0
#                  Wallpapers FN Five seven                            0
#                  Wallpapers FN FAL Light Automatic Rifle             0
# Name: Reviews, Length: 9744, dtype: int64
